# %% [markdown]
# # Эволюция GRA-Ethnos
# Пример анализа динамики народа.

# %%
import sys
sys.path.append('..')
from simulations.run_ethnos import create_diverse_ethnos
from simulations.visualization import plot_j_history, plot_identity_stability

ethnos = create_diverse_ethnos(20)
ethnos.run(steps=100, verbose=False)
plot_j_history(ethnos)
plot_identity_stability(ethnos)
